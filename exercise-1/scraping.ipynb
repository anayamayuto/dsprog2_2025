# %%
pip install pandas
# Out:
# 2228.41s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Collecting pandas
#   Using cached pandas-2.3.3-cp312-cp312-macosx_11_0_arm64.whl.metadata (91 kB)
# Collecting numpy>=1.26.0 (from pandas)
#   Using cached numpy-2.3.5-cp312-cp312-macosx_14_0_arm64.whl.metadata (62 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/yutop/github/dsprog2_2025/dsprog2_2025/.venv/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: tzdata>=2022.7 in /Users/yutop/github/dsprog2_2025/dsprog2_2025/.venv/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/yutop/github/dsprog2_2025/dsprog2_2025/.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Using cached pandas-2.3.3-cp312-cp312-macosx_11_0_arm64.whl (10.7 MB)
# Using cached numpy-2.3.5-cp312-cp312-macosx_14_0_arm64.whl (5.1 MB)
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Installing collected packages: pytz, numpy, pandas
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [pandas]2m2/3 [pandas]
# Successfully installed numpy-2.3.5 pandas-2.3.3 pytz-2025.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from bs4 import BeautifulSoup
import time
import sqlite3
import random

# データベースの設定
DB_FILE = 'github_repos.db'

def create_database():
    """データベースとテーブルを作成する"""
    conn = sqlite3.connect(DB_FILE)
    cursor = conn.cursor()
    
    # リポジトリ情報を保存するテーブルを作成
    cursor.execute('''
    CREATE TABLE IF NOT EXISTS repositories (
        id INTEGER PRIMARY KEY AUTOINCREMENT,
        repo_name TEXT,
        stars INTEGER,
        language TEXT,
        scrape_date TIMESTAMP DEFAULT CURRENT_TIMESTAMP
    )
    ''')
    
    conn.commit()
    conn.close()
    print("データベースとテーブルを作成しました")

def scrape_github_page(page_num):
    """指定されたページ番号のGitHubリポジトリ検索結果をスクレイピングする"""
    # 各リクエスト前に1秒待機（指定通り）
    time.sleep(1)
    
    url = f"https://github.com/search?q=google&type=repositories&p={page_num}"
    
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
    
    try:
        response = requests.get(url, headers=headers)
        
        if response.status_code != 200:
            print(f"エラー: ページ {page_num} - ステータスコード {response.status_code}")
            return []
        
        soup = BeautifulSoup(response.text, 'html.parser')
        
        # リポジトリコンテナを検出（新旧デザイン対応）
        repo_items = []
        
        # 新デザイン用
        new_design = soup.select('div[data-testid="results-list"] > div')
        if new_design:
            repo_items = new_design
            print(f"ページ {page_num} で {len(repo_items)} 件のリポジトリを検出")
        else:
            # 従来のデザイン用
            old_design = soup.select('ul.repo-list > li')
            if old_design:
                repo_items = old_design
                print(f"ページ {page_num} で {len(repo_items)} 件のリポジトリを検出")
        
        if not repo_items:
            print(f"ページ {page_num} にリポジトリが見つかりませんでした。")
            return []
        
        repos = []
        for repo in repo_items:
            # リポジトリ名を取得（複数のセレクタを試す）
            repo_name = None
            repo_selectors = [
                'a[data-testid="result-heading-title"]',
                'a.v-align-middle',
                'h3 a',
                'a.text-bold'
            ]
            
            for selector in repo_selectors:
                element = repo.select_one(selector)
                if element:
                    repo_name = element.text.strip()
                    break
            
            # スター数を取得（複数のセレクタを試す）
            stars = None  # デフォルト値を None に設定
            star_selectors = [
                'a[href*="stargazers"]',
                'a.Link--muted [aria-label*="star"]',
                'a.social-count'
            ]
            
            for selector in star_selectors:
                element = repo.select_one(selector)
                if element:
                    star_text = element.text.strip().replace(',', '')
                    try:
                        if 'k' in star_text.lower():
                            stars = int(float(star_text.lower().replace('k', '')) * 1000)
                        else:
                            stars = int(star_text)
                    except ValueError:
                        stars = None  # 変換できない場合は None のまま
                    break
            
            # 言語を取得（複数のセレクタを試す）
            language = None  # デフォルト値を None に設定
            language_selectors = [
                'span[itemprop="programmingLanguage"]',
                'span.color-fg-muted span.d-inline-block',
                'span.repo-language-color + span'
            ]
            
            for selector in language_selectors:
                element = repo.select_one(selector)
                if element:
                    language = element.text.strip()
                    break
            
            # 言語の円形マークの後のテキストを探す
            if language is None:
                lang_circles = repo.select('span.repo-language-color')
                for circle in lang_circles:
                    next_sibling = circle.find_next_sibling()
                    if next_sibling:
                        language = next_sibling.text.strip()
                        break
            
            print(f"リポジトリ: {repo_name}, スター数: {stars}, 言語: {language}")
            
            repos.append({
                'repo_name': repo_name,
                'stars': stars,
                'language': language
            })
        
        return repos
        
    except Exception as e:
        print(f"ページ {page_num} の処理中にエラー: {e}")
        return []

def save_to_database(repos):
    """リポジトリ情報をデータベースに保存する"""
    if not repos:
        return 0
    
    conn = sqlite3.connect(DB_FILE)
    cursor = conn.cursor()
    
    count = 0
    for repo in repos:
        try:
            cursor.execute(
                "INSERT INTO repositories (repo_name, stars, language) VALUES (?, ?, ?)",
                (repo['repo_name'], repo['stars'], repo['language'])
            )
            count += 1
        except sqlite3.Error as e:
            print(f"データベース保存エラー: {e}")
    
    conn.commit()
    conn.close()
    return count

def display_all_from_database():
    """データベースから全てのリポジトリ情報を取得して表示する"""
    conn = sqlite3.connect(DB_FILE)
    cursor = conn.cursor()
    
    print("\n=== データベースに保存された全リポジトリ情報 ===")
    
    # 総レコード数を取得
    cursor.execute("SELECT COUNT(*) FROM repositories")
    total = cursor.fetchone()[0]
    print(f"総レコード数: {total}")
    
    # 全てのレコードを取得
    cursor.execute("SELECT id, repo_name, stars, language, scrape_date FROM repositories")
    
    # 列名を表示
    print("\nID | リポジトリ名 | スター数 | 言語 | 取得日時")
    print("-" * 80)
    
    # 全レコードを表示
    for row in cursor.fetchall():
        id, repo_name, stars, language, scrape_date = row
        
        # NULL値の場合は "NULL" と表示
        if repo_name is None: repo_name = "NULL"
        if stars is None: stars = "NULL"
        if language is None: language = "NULL"
        
        print(f"{id} | {repo_name} | {stars} | {language} | {scrape_date}")
    
    conn.close()

def main():
    """メイン実行関数"""
    # データベースの作成
    create_database()
    
    # 保存されたリポジトリ数をカウント
    total_repos = 0
    
    # 100ページ分のリポジトリ情報を取得
    for page in range(1, 101):
        print(f"\n=== ページ {page}/100 の処理を開始 ===")
        
        # リポジトリ情報のスクレイピング
        repos = scrape_github_page(page)
        
        if not repos:
            print(f"ページ {page} からリポジトリを取得できませんでした。")
            continue
        
        # データベースに保存
        saved = save_to_database(repos)
        total_repos += saved
        print(f"ページ {page} から {saved} 件のリポジトリ情報をデータベースに保存しました")
        
        # ページ間の待機時間を設定（レート制限回避のため）
        wait_time = random.uniform(2, 4)
        print(f"次のページを取得する前に {wait_time:.1f} 秒待機します...")
        time.sleep(wait_time)
    
    # 保存結果の表示
    print(f"\n合計 {total_repos} 件のリポジトリ情報をデータベースに保存しました")
    
    # データベースから全データを表示
    display_all_from_database()

if __name__ == "__main__":
    main()
# Out:
# データベースとテーブルを作成しました
#
# === ページ 1/100 の処理を開始 ===
# ページ 1 で 10 件のリポジトリを検出
# リポジトリ: gaowanlu/google, スター数: 341, 言語: None
# リポジトリ: google/googletest, スター数: 37500, 言語: None
# リポジトリ: google-research/google-research, スター数: 36800, 言語: None
# リポジトリ: googleapis/googleapis, スター数: 8300, 言語: None
# リポジトリ: NikolaiT/GoogleScraper, スター数: 2800, 言語: None
# リポジトリ: PHPGangsta/GoogleAuthenticator, スター数: 2300, 言語: None
# リポジトリ: zh-google-styleguide/zh-google-styleguide, スター数: 10900, 言語: None
# リポジトリ: opauth/google, スター数: 120, 言語: None
# リポジトリ: googlesamples/google-services, スター数: 3200, 言語: None
# リポジトリ: Ponderfly/GoogleTranslateIpCheck, スター数: 5000, 言語: None
# ページ 1 から 10 件のリポジトリ情報をデータベースに保存しました
# 次のページを取得する前に 3.0 秒待機します...
#
# === ページ 2/100 の処理を開始 ===
# エラー: ページ 2 - ステータスコード 429
# ページ 2 からリポジトリを取得できませんでした。
#
# === ページ 3/100 の処理を開始 ===
# ページ 3 で 10 件のリポジトリを検出
# リポジトリ: googleapis/google-cloud-python, スター数: 5200, 言語: None
# リポジトリ: google/google-authenticator, スター数: 5300, 言語: None
# リポジトリ: priyankavergadia/google-cloud-4-words, スター数: 8200, 言語: None
# リポジトリ: TheLastGimbus/GooglePhotosTakeoutHelper, スター数: 5200, 言語: None
# リポジトリ: jarun/googler, スター数: 6200, 言語: None
# リポジトリ: justjavac/Google-IPs, スター数: 3500, 言語: None
# リポジトリ: wstrange/GoogleAuth, スター数: 1100, 言語: None
# リポジトリ: googleapis/google-cloud-go, スター数: 4400, 言語: None
# リポジトリ: hashicorp/terraform-provider-google, スター数: 2600, 言語: None
# リポジトリ: react-native-google-signin/google-signin, スター数: 3500, 言語: None
# ページ 3 から 10 件のリポジトリ情報をデータベースに保存しました
# 次のページを取得する前に 2.2 秒待機します...
#
# === ページ 4/100 の処理を開始 ===
# エラー: ページ 4 - ステータスコード 429
# ページ 4 からリポジトリを取得できませんでした。
#
# === ページ 5/100 の処理を開始 ===
# エラー: ページ 5 - ステータスコード 429
# ページ 5 からリポジトリを取得できませんでした。
#
# === ページ 6/100 の処理を開始 ===
# エラー: ページ 6 - ステータスコード 429
# ページ 6 からリポジトリを取得できませんでした。
#
# === ページ 7/100 の処理を開始 ===
# ページ 7 で 10 件のリポジトリを検出
# リポジトリ: matheuss/google-translate-api, スター数: 3100, 言語: None
# リポジトリ: google/iosched, スター数: 21800, 言語: None
# リポジトリ: Kerrick/google, スター数: 116, 言語: None
# リポジトリ: google/automl, スター数: 6400, 言語: None
# リポジトリ: meibenjin/GoogleSearchCrawler, スター数: 401, 言語: None
# リポジトリ: MarioVilas/googlesearch, スター数: 1200, 言語: None
# リポジトリ: googleapis/google-api-ruby-client, スター数: 2900, 言語: None
# リポジトリ: justjavac/ReplaceGoogleCDN, スター数: 3600, 言語: None
# リポジトリ: terraform-google-modules/terraform-google-network, スター数: 473, 言語: None
# リポジトリ: terraform-google-modules/terraform-google-kubernetes-engine, スター数: 1200, 言語: None
# ページ 7 から 10 件のリポジトリ情報をデータベースに保存しました
# 次のページを取得する前に 2.7 秒待機します...
#
# === ページ 8/100 の処理を開始 ===
# エラー: ページ 8 - ステータスコード 429
# ページ 8 からリポジトリを取得できませんでした。
#
# === ページ 9/100 の処理を開始 ===
# エラー: ページ 9 - ステータスコード 429
# ページ 9 からリポジトリを取得できませんでした。
#
# === ページ 10/100 の処理を開始 ===
# エラー: ページ 10 - ステータスコード 429
# ページ 10 からリポジトリを取得できませんでした。
#
# === ページ 11/100 の処理を開始 ===
# エラー: ページ 11 - ステータスコード 429
# ページ 11 からリポジトリを取得できませんでした。
#
# === ページ 12/100 の処理を開始 ===
# ページ 12 で 10 件のリポジトリを検出
# リポジトリ: FaridSafi/react-native-google-places-autocomplete, スター数: 2100, 言語: None
# リポジトリ: anthonyjgrove/react-google-login, スター数: 1800, 言語: None
# リポジトリ: mgechev/google-interview-preparation-problems, スター数: 3200, 言語: None
# リポジトリ: omkarcloud/google-maps-scraper, スター数: 2200, 言語: None
# リポジトリ: better319/google-access-helper, スター数: 55, 言語: None
# リポジトリ: darcyliu/google-styleguide, スター数: 1400, 言語: None
# リポジトリ: APCSLowell/GoogleBillboard, スター数: 3, 言語: None
# リポジトリ: prasmussen/gdrive, スター数: 9000, 言語: None
# リポジトリ: BrandonPotter/GoogleAuthenticator, スター数: 390, 言語: None
# リポジトリ: egirault/googleplay-api, スター数: 895, 言語: None
# ページ 12 から 10 件のリポジトリ情報をデータベースに保存しました
# 次のページを取得する前に 3.0 秒待機します...
#
# === ページ 13/100 の処理を開始 ===
# ページ 13 で 10 件のリポジトリを検出
# リポジトリ: Stichoza/google-translate-php, スター数: 1900, 言語: None
# リポジトリ: lypeer/GoogleClock, スター数: 790, 言語: None
# リポジトリ: GuillaumeLeclerc/vue-google-maps, スター数: 562, 言語: None
# リポジトリ: google/fonts, スター数: 19400, 言語: None
# リポジトリ: aryanvikash/Google-Drive-Uploader, スター数: 306, 言語: None
# リポジトリ: errata-ai/Google, スター数: 78, 言語: None
# リポジトリ: EddyVerbruggen/cordova-plugin-googleplus, スター数: 567, 言語: None
# リポジトリ: GoogleCloudPlatform/python-docs-samples, スター数: 7900, 言語: None
# リポジトリ: gosom/google-maps-scraper, スター数: 2500, 言語: None
# リポジトリ: cobaltdisco/Google-Chinese-Results-Blocklist, スター数: 7500, 言語: None
# ページ 13 から 10 件のリポジトリ情報をデータベースに保存しました
# 次のページを取得する前に 2.8 秒待機します...
#
# === ページ 14/100 の処理を開始 ===
# ページ 14 で 10 件のリポジトリを検出
# リポジトリ: googleapis/google-cloud-php, スター数: 1200, 言語: None
# リポジトリ: ssnhd/googlevoice, スター数: 2000, 言語: None
# リポジトリ: googleapis/elixir-google-api, スター数: 1100, 言語: None
# リポジトリ: oazabir/GoogleDoc2Html, スター数: 142, 言語: None
# リポジトリ: googleapis/google-api-dotnet-client, スター数: 1500, 言語: None
# リポジトリ: rakannimer/react-google-charts, スター数: 1700, 言語: None
# リポジトリ: google/it-cert-automation-practice, スター数: 986, 言語: None
# リポジトリ: JustFly1984/react-google-maps-api, スター数: 2000, 言語: None
# リポジトリ: google/google-api-java-client-samples, スター数: 741, 言語: None
# リポジトリ: googleads/google-ads-python, スター数: 627, 言語: None
# ページ 14 から 10 件のリポジトリ情報をデータベースに保存しました
# 次のページを取得する前に 3.7 秒待機します...
#
# === ページ 15/100 の処理を開始 ===
# エラー: ページ 15 - ステータスコード 429
# ページ 15 からリポジトリを取得できませんでした。
#
# === ページ 16/100 の処理を開始 ===
# ページ 16 で 10 件のリポジトリを検出
# リポジトリ: elmoallistair/google-it-automation, スター数: 516, 言語: None
# リポジトリ: apneadiving/Google-Maps-for-Rails, スター数: 2300, 言語: None
# リポジトリ: googleapis/google-http-java-client, スター数: 1400, 言語: None
# リポジトリ: Iceloof/GoogleNews, スター数: 374, 言語: None
# リポジトリ: googleapis/google-auth-library-nodejs, スター数: 1900, 言語: None
# リポジトリ: Ibit-to/google-unlocked, スター数: 2300, 言語: None
# リポジトリ: Melvin-Abraham/Google-Assistant-Unofficial-Desktop-Client, スター数: 3600, 言語: None
# リポジトリ: cgapps/vendor_google, スター数: 345, 言語: None
# リポジトリ: jennybc/googlesheets, スター数: 784, 言語: None
# リポジトリ: zquestz/omniauth-google-oauth2, スター数: 1500, 言語: None
# ページ 16 から 10 件のリポジトリ情報をデータベースに保存しました
# 次のページを取得する前に 3.2 秒待機します...
#
# === ページ 17/100 の処理を開始 ===
# ページ 17 で 10 件のリポジトリを検出
# リポジトリ: xamarin/GoogleApisForiOSComponents, スター数: 220, 言語: None
# リポジトリ: googleapis/google-cloud-cpp, スター数: 628, 言語: None
# リポジトリ: xamarin/GooglePlayServicesComponents, スター数: 314, 言語: None
# リポジトリ: chimbori/google-calendar-crx, スター数: 952, 言語: None
# リポジトリ: entaq/GoogleAppsScript, スター数: 266, 言語: None
# リポジトリ: Kdyby/Google, スター数: 25, 言語: None
# リポジトリ: hongtaocai/googlefinance, スター数: 807, 言語: None
# リポジトリ: macek/google_pacman, スター数: 504, 言語: None
# リポジトリ: firmai/awesome-google-colab, スター数: 1500, 言語: None
# リポジトリ: Proviesec/google-dorks, スター数: 1100, 言語: None
# ページ 17 から 10 件のリポジトリ情報をデータベースに保存しました
# 次のページを取得する前に 3.8 秒待機します...
#
# === ページ 18/100 の処理を開始 ===
# エラー: ページ 18 - ステータスコード 429
# ページ 18 からリポジトリを取得できませんでした。
#
# === ページ 19/100 の処理を開始 ===
# エラー: ページ 19 - ステータスコード 429
# ページ 19 からリポジトリを取得できませんでした。
#
# === ページ 20/100 の処理を開始 ===
# エラー: ページ 20 - ステータスコード 429
# ページ 20 からリポジトリを取得できませんでした。
#
# === ページ 21/100 の処理を開始 ===
# エラー: ページ 21 - ステータスコード 429
# ページ 21 からリポジトリを取得できませんでした。
#
# === ページ 22/100 の処理を開始 ===
# エラー: ページ 22 - ステータスコード 429
# ページ 22 からリポジトリを取得できませんでした。
#
# === ページ 23/100 の処理を開始 ===
# エラー: ページ 23 - ステータスコード 429
# ページ 23 からリポジトリを取得できませんでした。
#
# === ページ 24/100 の処理を開始 ===
# エラー: ページ 24 - ステータスコード 429
# ページ 24 からリポジトリを取得できませんでした。
#
# === ページ 25/100 の処理を開始 ===
# エラー: ページ 25 - ステータスコード 429
# ページ 25 からリポジトリを取得できませんでした。
#
# === ページ 26/100 の処理を開始 ===
# エラー: ページ 26 - ステータスコード 429
# ページ 26 からリポジトリを取得できませんでした。
#
# === ページ 27/100 の処理を開始 ===
# ページ 27 で 10 件のリポジトリを検出
# リポジトリ: Akdeniz/google-play-crawler, スター数: 588, 言語: None
# リポジトリ: googleapis/google-oauth-java-client, スター数: 644, 言語: None
# リポジトリ: tidyverse/googlesheets4, スター数: 372, 言語: None
# リポジトリ: react-native-google-cast/react-native-google-cast, スター数: 691, 言語: None
# リポジトリ: google/earthenterprise, スター数: 2700, 言語: None
# リポジトリ: gaspa93/googlemaps-scraper, スター数: 485, 言語: None
# リポジトリ: cvdfoundation/google-landmark, スター数: 817, 言語: None
# リポジトリ: enuchi/React-Google-Apps-Script, スター数: 1500, 言語: None
# リポジトリ: googleapis/google-api-java-client-services, スター数: 692, 言語: None
# リポジトリ: fysoul17/google_maps_place_picker, スター数: 229, 言語: None
# ページ 27 から 10 件のリポジトリ情報をデータベースに保存しました
# 次のページを取得する前に 2.0 秒待機します...
#
# === ページ 28/100 の処理を開始 ===
# ページ 28 で 10 件のリポジトリを検出
# リポジトリ: GoogleCloudPlatform/awesome-google-cloud, スター数: 876, 言語: None
# リポジトリ: googleworkspace/apps-script-samples, スター数: 5000, 言語: None
# リポジトリ: rafiuddinkhan/Yolo-Training-GoogleColab, スター数: 170, 言語: None
# リポジトリ: tolu360/react-native-google-places, スター数: 569, 言語: None
# リポジトリ: r0adkll/upload-google-play, スター数: 924, 言語: None
# リポジトリ: FugiTech/google-meet-grid-view, スター数: 617, 言語: None
# リポジトリ: googleapis/google-auth-library-php, スター数: 1400, 言語: None
# リポジトリ: dozoisch/react-google-recaptcha, スター数: 1100, 言語: None
# リポジトリ: heroku/heroku-buildpack-google-chrome, スター数: 298, 言語: None
# リポジトリ: alx-xlx/goindex, スター数: 1300, 言語: None
# ページ 28 から 10 件のリポジトリ情報をデータベースに保存しました
# 次のページを取得する前に 2.4 秒待機します...
#
# === ページ 29/100 の処理を開始 ===
# エラー: ページ 29 - ステータスコード 429
# ページ 29 からリポジトリを取得できませんでした。
#
# === ページ 30/100 の処理を開始 ===
# ページ 30 で 10 件のリポジトリを検出
# リポジトリ: mattwilson1024/google-photos-exif, スター数: 1000, 言語: None
# リポジトリ: nlintz/TensorFlow-Tutorials, スター数: 6000, 言語: None
# リポジトリ: jmartinesp/GoogleNavigationDrawerMenu, スター数: 275, 言語: None
# リポジトリ: K0rz3n/GoogleHacking-Page, スター数: 290, 言語: None
# リポジトリ: androidthings/sample-googleassistant, スター数: 468, 言語: None
# リポジトリ: Ayush7-BIT/Google-Facilitator-Program-Solutions, スター数: 147, 言語: None
# リポジトリ: AbhimanyuForiOS/GoogleNewsStandAnimation, スター数: 659, 言語: None
# リポジトリ: hermanho/MMM-GooglePhotos, スター数: 192, 言語: None
# リポジトリ: revolunet/angular-google-analytics, スター数: 649, 言語: None
# リポジトリ: googleapis/google-auth-library-ruby, スター数: 496, 言語: None
# ページ 30 から 10 件のリポジトリ情報をデータベースに保存しました
# 次のページを取得する前に 3.3 秒待機します...
#
# === ページ 31/100 の処理を開始 ===
# ページ 31 で 10 件のリポジトリを検出
# リポジトリ: PMassicotte/gtrendsR, スター数: 363, 言語: None
# リポジトリ: idehub/react-native-google-analytics-bridge, スター数: 1200, 言語: None
# リポジトリ: HandsOnDataViz/leaflet-maps-with-google-sheets, スター数: 158, 言語: None
# リポジトリ: hpneo/gmaps, スター数: 7000, 言語: None
# リポジトリ: cevoaustralia/aws-google-auth, スター数: 546, 言語: None
# リポジトリ: playgameservices/play-games-plugin-for-unity, スター数: 3600, 言語: None
# リポジトリ: sahava/GoogleTagManagerTemplates, スター数: 203, 言語: None
# リポジトリ: Freika/dawarich, スター数: 7300, 言語: None
# リポジトリ: googleads/googleads-shopping-samples, スター数: 201, 言語: None
# リポジトリ: googleapis/google-auth-library-java, スター数: 450, 言語: None
# ページ 31 から 10 件のリポジトリ情報をデータベースに保存しました
# 次のページを取得する前に 3.3 秒待機します...
#
# === ページ 32/100 の処理を開始 ===
# ページ 32 で 10 件のリポジトリを検出
# リポジトリ: noelportugal/google-home-notifier, スター数: 575, 言語: None
# リポジトリ: google/WebFundamentals, スター数: 13900, 言語: None
# リポジトリ: actions-on-google/actions-on-google-nodejs, スター数: 896, 言語: None
# リポジトリ: ohyicong/Google-Image-Scraper, スター数: 543, 言語: None
# リポジトリ: Iku/Google-Forms-to-Discord, スター数: 556, 言語: None
# リポジトリ: FKLC/Torrent-To-Google-Drive-Downloader, スター数: 389, 言語: None
# リポジトリ: alexpechkarev/google-maps, スター数: 558, 言語: None
# リポジトリ: slimkrazy/python-google-places, スター数: 523, 言語: None
# リポジトリ: labbots/google-drive-upload, スター数: 732, 言語: None
# リポジトリ: femmebot/google-type, スター数: 1000, 言語: None
# ページ 32 から 10 件のリポジトリ情報をデータベースに保存しました
# 次のページを取得する前に 3.5 秒待機します...
#
# === ページ 33/100 の処理を開始 ===
# エラー: ページ 33 - ステータスコード 429
# ページ 33 からリポジトリを取得できませんでした。
#
# === ページ 34/100 の処理を開始 ===
# ページ 34 で 10 件のリポジトリを検出
# リポジトリ: BaltiApps/Pixelify-Google-Photos, スター数: 1500, 言語: None
# リポジトリ: google/googleapis.dart, スター数: 408, 言語: None
# リポジトリ: Code-Bullet/Google-Chrome-Dino-Game-AI, スター数: 689, 言語: None
# リポジトリ: elmoallistair/google-it-support, スター数: 338, 言語: None
# リポジトリ: humazed/google_map_location_picker, スター数: 206, 言語: None
# リポジトリ: brendanhay/gogol, スター数: 294, 言語: None
# リポジトリ: egeloen/ivory-google-map, スター数: 323, 言語: None
# リポジトリ: BlankCoders/GoogleKickStart2020_Solutions, スター数: 188, 言語: None
# リポジトリ: hariharan-uno/google, スター数: 27, 言語: None
# リポジトリ: jmelosegui/GooglemapMvc, スター数: 118, 言語: None
# ページ 34 から 10 件のリポジトリ情報をデータベースに保存しました
# 次のページを取得する前に 3.6 秒待機します...
#
# === ページ 35/100 の処理を開始 ===
# エラー: ページ 35 - ステータスコード 429
# ページ 35 からリポジトリを取得できませんでした。
#
# === ページ 36/100 の処理を開始 ===
# エラー: ページ 36 - ステータスコード 429
# ページ 36 からリポジトリを取得できませんでした。
#
# === ページ 37/100 の処理を開始 ===
# ページ 37 で 10 件のリポジトリを検出
# リポジトリ: yireo/Yireo_GoogleTagManager2, スター数: 163, 言語: None
# リポジトリ: jaredhanson/passport-google-oauth2, スター数: 839, 言語: None
# リポジトリ: adrianhajdin/project_google_clone, スター数: 470, 言語: None
# リポジトリ: GoogleCloudPlatform/magic-modules, スター数: 908, 言語: None
# リポジトリ: invertase/react-native-google-mobile-ads, スター数: 935, 言語: None
# リポジトリ: ArdiArtani/Google-Drive-Player-Script, スター数: 319, 言語: None
# リポジトリ: google-gemini/starter-applets, スター数: 1200, 言語: None
# リポジトリ: tgtsml/QtInputMethod_GooglePinyin, スター数: 131, 言語: None
# リポジトリ: GoogleCloudPlatform/nodejs-docs-samples, スター数: 2900, 言語: None
# リポジトリ: howie6879/magic_google, スター数: 408, 言語: None
# ページ 37 から 10 件のリポジトリ情報をデータベースに保存しました
# 次のページを取得する前に 3.8 秒待機します...
#
# === ページ 38/100 の処理を開始 ===
# エラー: ページ 38 - ステータスコード 429
# ページ 38 からリポジトリを取得できませんでした。
#
# === ページ 39/100 の処理を開始 ===
# エラー: ページ 39 - ステータスコード 429
# ページ 39 からリポジトリを取得できませんでした。
#
# === ページ 40/100 の処理を開始 ===
# エラー: ページ 40 - ステータスコード 429
# ページ 40 からリポジトリを取得できませんでした。
#
# === ページ 41/100 の処理を開始 ===
# エラー: ページ 41 - ステータスコード 429
# ページ 41 からリポジトリを取得できませんでした。
#
# === ページ 42/100 の処理を開始 ===
# エラー: ページ 42 - ステータスコード 429
# ページ 42 からリポジトリを取得できませんでした。
#
# === ページ 43/100 の処理を開始 ===
# エラー: ページ 43 - ステータスコード 429
# ページ 43 からリポジトリを取得できませんでした。
#
# === ページ 44/100 の処理を開始 ===
# エラー: ページ 44 - ステータスコード 429
# ページ 44 からリポジトリを取得できませんでした。
#
# === ページ 45/100 の処理を開始 ===
# エラー: ページ 45 - ステータスコード 429
# ページ 45 からリポジトリを取得できませんでした。
#
# === ページ 46/100 の処理を開始 ===
# エラー: ページ 46 - ステータスコード 429
# ページ 46 からリポジトリを取得できませんでした。
#
# === ページ 47/100 の処理を開始 ===
# ページ 47 で 10 件のリポジトリを検出
# リポジトリ: priyankavergadia/AppointmentScheduler-GoogleCalendar, スター数: 97, 言語: None
# リポジトリ: daviddrysdale/python-phonenumbers, スター数: 3700, 言語: None
# リポジトリ: n3a9/google-foobar, スター数: 301, 言語: None
# リポジトリ: igrigorik/videospeed, スター数: 4200, 言語: None
# リポジトリ: google/google-input-tools, スター数: 265, 言語: None
# リポジトリ: kubernetes/cloud-provider-gcp, スター数: 144, 言語: None
# リポジトリ: randomBrainstormer/MMM-GoogleCalendar, スター数: 89, 言語: None
# リポジトリ: JasonSanford/geojson-google-maps, スター数: 323, 言語: None
# リポジトリ: paralelo14/google_explorer, スター数: 205, 言語: None
# リポジトリ: steverichey/google-play-badge-svg, スター数: 183, 言語: None
# ページ 47 から 10 件のリポジトリ情報をデータベースに保存しました
# 次のページを取得する前に 2.7 秒待機します...
#
# === ページ 48/100 の処理を開始 ===
# エラー: ページ 48 - ステータスコード 429
# ページ 48 からリポジトリを取得できませんでした。
#
# === ページ 49/100 の処理を開始 ===
# エラー: ページ 49 - ステータスコード 429
# ページ 49 からリポジトリを取得できませんでした。
#
# === ページ 50/100 の処理を開始 ===
# エラー: ページ 50 - ステータスコード 429
# ページ 50 からリポジトリを取得できませんでした。
#
# === ページ 51/100 の処理を開始 ===
# エラー: ページ 51 - ステータスコード 429
# ページ 51 からリポジトリを取得できませんでした。
#
# === ページ 52/100 の処理を開始 ===
# ページ 52 で 10 件のリポジトリを検出
# リポジトリ: neokree/GoogleNavigationDrawer, スター数: 157, 言語: None
# リポジトリ: stepancheg/rust-protobuf, スター数: 3000, 言語: None
# リポジトリ: zeantsoi/GoogleBooks, スター数: 112, 言語: None
# リポジトリ: Akryum/vue-googlemaps, スター数: 533, 言語: None
# リポジトリ: googleworkspace/python-samples, スター数: 1300, 言語: None
# リポジトリ: gabrielpacheco23/google-translator, スター数: 190, 言語: None
# リポジトリ: zjuyxy/google200, スター数: 106, 言語: None
# リポジトリ: veip007/GV_GoogleVoice, スター数: 149, 言語: None
# リポジトリ: Gowee/GoogleMirror, スター数: 89, 言語: None
# リポジトリ: pkpio/fitbit-googlefit, スター数: 508, 言語: None
# ページ 52 から 10 件のリポジトリ情報をデータベースに保存しました
# 次のページを取得する前に 2.9 秒待機します...
#
# === ページ 53/100 の処理を開始 ===
# エラー: ページ 53 - ステータスコード 429
# ページ 53 からリポジトリを取得できませんでした。
#
# === ページ 54/100 の処理を開始 ===
# ページ 54 で 10 件のリポジトリを検出
# リポジトリ: GoogleCloudPlatform/java-docs-samples, スター数: 1900, 言語: None
# リポジトリ: joshcarty/google-searchconsole, スター数: 233, 言語: None
# リポジトリ: vadimdemedes/google-images, スター数: 307, 言語: None
# リポジトリ: madisona/django-google-maps, スター数: 282, 言語: None
# リポジトリ: googleanalytics/google-analytics-plugin-for-unity, スター数: 397, 言語: None
# リポジトリ: google/coding-competitions-archive, スター数: 1300, 言語: None
# リポジトリ: TheMuppets/proprietary_vendor_google, スター数: 101, 言語: None
# リポジトリ: RubyMoney/google_currency, スター数: 182, 言語: None
# リポジトリ: subnub/myDrive, スター数: 4100, 言語: None
# リポジトリ: pulkitjalan/google-apiclient, スター数: 257, 言語: None
# ページ 54 から 10 件のリポジトリ情報をデータベースに保存しました
# 次のページを取得する前に 2.9 秒待機します...
#
# === ページ 55/100 の処理を開始 ===
# エラー: ページ 55 - ステータスコード 429
# ページ 55 からリポジトリを取得できませんでした。
#
# === ページ 56/100 の処理を開始 ===
# ページ 56 で 10 件のリポジトリを検出
# リポジトリ: tidyverse/googledrive, スター数: 336, 言語: None
# リポジトリ: roboguice/roboguice, スター数: 3800, 言語: None
# リポジトリ: Hameds/GoogleBackup, スター数: 284, 言語: None
# リポジトリ: mate-academy/py-can-access-google-page, スター数: 2, 言語: None
# リポジトリ: chocoboyx/GoogleSheet_DiscordBot, スター数: 7, 言語: None
# リポジトリ: terraform-google-modules/terraform-google-pubsub, スター数: 107, 言語: None
# リポジトリ: spatie/laravel-googletagmanager, スター数: 430, 言語: None
# リポジトリ: xfslove/alfred-google-translate, スター数: 617, 言語: None
# リポジトリ: smol-ai/GodMode, スター数: 4300, 言語: None
# リポジトリ: google/google-api-ruby-client-samples, スター数: 330, 言語: None
# ページ 56 から 10 件のリポジトリ情報をデータベースに保存しました
# 次のページを取得する前に 2.2 秒待機します...
#
# === ページ 57/100 の処理を開始 ===
# エラー: ページ 57 - ステータスコード 429
# ページ 57 からリポジトリを取得できませんでした。
#
# === ページ 58/100 の処理を開始 ===
# ページ 58 で 10 件のリポジトリを検出
# リポジトリ: 5iux/sou, スター数: 940, 言語: None
# リポジトリ: CVM/Magento_GoogleTagManager, スター数: 67, 言語: None
# リポジトリ: forseti-security/terraform-google-forseti, スター数: 133, 言語: None
# リポジトリ: tanmuhittin/laravel-google-translate, スター数: 430, 言語: None
# リポジトリ: DarkSnakeGang/GoogleSnakeModLoader, スター数: 50, 言語: None
# リポジトリ: jignesh13/googlecalendar, スター数: 178, 言語: None
# リポジトリ: akshaaatt/Google-IAP, スター数: 282, 言語: None
# リポジトリ: GoogleWebComponents/google-analytics, スター数: 186, 言語: None
# リポジトリ: thephpleague/oauth2-google, スター数: 410, 言語: None
# リポジトリ: jupyterlab/jupyterlab-google-drive, スター数: 402, 言語: None
# ページ 58 から 10 件のリポジトリ情報をデータベースに保存しました
# 次のページを取得する前に 3.7 秒待機します...
#
# === ページ 59/100 の処理を開始 ===
# ページ 59 で 10 件のリポジトリを検出
# リポジトリ: bpillon/google_maps_cluster_manager, スター数: 140, 言語: None
# リポジトリ: devstark-com/vue-google-charts, スター数: 447, 言語: None
# リポジトリ: pseudomuto/protoc-gen-doc, スター数: 2800, 言語: None
# リポジトリ: GoogleCloudPlatform/terraform-google-cloud-run, スター数: 187, 言語: None
# リポジトリ: maximepvrt/angular-google-gapi, スター数: 174, 言語: None
# リポジトリ: googleads/googleads-dfa-reporting-samples, スター数: 109, 言語: None
# リポジトリ: akexorcist/GoogleDirectionAndPlaceLibrary, スター数: 117, 言語: None
# リポジトリ: google-pay/google-pay-button, スター数: 288, 言語: None
# リポジトリ: googlesamples/web-fundamentals, スター数: 315, 言語: None
# リポジトリ: googlearchive/drive-zipextractor, スター数: 441, 言語: None
# ページ 59 から 10 件のリポジトリ情報をデータベースに保存しました
# 次のページを取得する前に 3.3 秒待機します...
#
# === ページ 60/100 の処理を開始 ===
# ページ 60 で 10 件のリポジトリを検出
# リポジトリ: charlierguo/gmail, スター数: 1800, 言語: None
# リポジトリ: bluevisiontec/GoogleShoppingApi, スター数: 69, 言語: None
# リポジトリ: invokable/laravel-google-sheets, スター数: 440, 言語: None
# リポジトリ: wanze/Google-Analytics-API-PHP, スター数: 261, 言語: None
# リポジトリ: cohnen/mcp-google-ads, スター数: 326, 言語: None
# リポジトリ: todc/todc-bootstrap, スター数: 2100, 言語: None
# リポジトリ: protocolbuffers/protobuf-go, スター数: 3300, 言語: None
# リポジトリ: andresoviedo/google-drive-ftp-adapter, スター数: 399, 言語: None
# リポジトリ: vladest/googlemaps, スター数: 148, 言語: None
# リポジトリ: google-map-react/google-map-react-examples, スター数: 148, 言語: None
# ページ 60 から 10 件のリポジトリ情報をデータベースに保存しました
# 次のページを取得する前に 2.8 秒待機します...
#
# === ページ 61/100 の処理を開始 ===
# エラー: ページ 61 - ステータスコード 429
# ページ 61 からリポジトリを取得できませんでした。
#
# === ページ 62/100 の処理を開始 ===
# エラー: ページ 62 - ステータスコード 429
# ページ 62 からリポジトリを取得できませんでした。
#
# === ページ 63/100 の処理を開始 ===
# エラー: ページ 63 - ステータスコード 429
# ページ 63 からリポジトリを取得できませんでした。
#
# === ページ 64/100 の処理を開始 ===
# エラー: ページ 64 - ステータスコード 429
# ページ 64 からリポジトリを取得できませんでした。
#
# === ページ 65/100 の処理を開始 ===
# エラー: ページ 65 - ステータスコード 429
# ページ 65 からリポジトリを取得できませんでした。
#
# === ページ 66/100 の処理を開始 ===
# エラー: ページ 66 - ステータスコード 429
# ページ 66 からリポジトリを取得できませんでした。
#
# === ページ 67/100 の処理を開始 ===
# エラー: ページ 67 - ステータスコード 429
# ページ 67 からリポジトリを取得できませんでした。
#
# === ページ 68/100 の処理を開始 ===
# エラー: ページ 68 - ステータスコード 429
# ページ 68 からリポジトリを取得できませんでした。
#
# === ページ 69/100 の処理を開始 ===
# エラー: ページ 69 - ステータスコード 429
# ページ 69 からリポジトリを取得できませんでした。
#
# === ページ 70/100 の処理を開始 ===
# ページ 70 で 10 件のリポジトリを検出
# リポジトリ: mister0/How-to-prepare-for-google-interview-SWE-SRE, スター数: 714, 言語: None
# リポジトリ: YoongiKim/AutoCrawler, スター数: 1700, 言語: None
# リポジトリ: zachysaur/Google, スター数: 13, 言語: None
# リポジトリ: chentinghao/download_google_drive, スター数: 201, 言語: None
# リポジトリ: visionmedia/google-search, スター数: 263, 言語: None
# リポジトリ: yireo-magento1/Yireo_GoogleTagManager, スター数: 56, 言語: None
# リポジトリ: aaronpk/Google-Voice-PHP-API, スター数: 224, 言語: None
# リポジトリ: mgilangjanuar/teledrive, スター数: 2000, 言語: None
# リポジトリ: capacitor-community/google-maps, スター数: 158, 言語: None
# リポジトリ: twinslash/redmine_omniauth_google, スター数: 99, 言語: None
# ページ 70 から 10 件のリポジトリ情報をデータベースに保存しました
# 次のページを取得する前に 2.7 秒待機します...
#
# === ページ 71/100 の処理を開始 ===
# ページ 71 で 10 件のリポジトリを検出
# リポジトリ: kakone/GoogleCast, スター数: 146, 言語: None
# リポジトリ: google/comprehensive-rust, スター数: 32299, 言語: None
# リポジトリ: CyanogenMod/android_device_lge_mako, スター数: 112, 言語: None
# リポジトリ: i8beef/HomeAutio.Mqtt.GoogleHome, スター数: 229, 言語: None
# リポジトリ: googleads/googleads-ima-android, スター数: 119, 言語: None
# リポジトリ: umano/AndroidSlidingUpPanel, スター数: 9500, 言語: None
# リポジトリ: gruntwork-io/terraform-google-sql, スター数: 92, 言語: None
# リポジトリ: myguybetter/GoogleIPHunter, スター数: 60, 言語: None
# リポジトリ: ivangrov/YOLOv3-GoogleColab, スター数: 79, 言語: None
# リポジトリ: firstcomdigital/Google-Interview-University, スター数: 240, 言語: None
# ページ 71 から 10 件のリポジトリ情報をデータベースに保存しました
# 次のページを取得する前に 2.9 秒待機します...
#
# === ページ 72/100 の処理を開始 ===
# エラー: ページ 72 - ステータスコード 429
# ページ 72 からリポジトリを取得できませんでした。
#
# === ページ 73/100 の処理を開始 ===
# エラー: ページ 73 - ステータスコード 429
# ページ 73 からリポジトリを取得できませんでした。
#
# === ページ 74/100 の処理を開始 ===
# ページ 74 で 10 件のリポジトリを検出
# リポジトリ: geniusgithub/AndroidDialer, スター数: 196, 言語: None
# リポジトリ: YukiGasai/obsidian-google-calendar, スター数: 464, 言語: None
# リポジトリ: retroplasma/earth-reverse-engineering, スター数: 2300, 言語: None
# リポジトリ: yrq110/TinyGoogle, スター数: 181, 言語: None
# リポジトリ: actions-on-google/dialogflow-facts-about-google-nodejs, スター数: 185, 言語: None
# リポジトリ: GoogleCloudPlatform/dotnet-docs-samples, スター数: 806, 言語: None
# リポジトリ: xob0t/Google-Photos-Toolkit, スター数: 636, 言語: None
# リポジトリ: marcferna/CakePHP-GoogleMapHelper, スター数: 63, 言語: None
# リポジトリ: clintecker/django-google-analytics, スター数: 172, 言語: None
# リポジトリ: angulartics/angulartics-google-analytics, スター数: 130, 言語: None
# ページ 74 から 10 件のリポジトリ情報をデータベースに保存しました
# 次のページを取得する前に 2.5 秒待機します...
#
# === ページ 75/100 の処理を開始 ===
# エラー: ページ 75 - ステータスコード 429
# ページ 75 からリポジトリを取得できませんでした。
#
# === ページ 76/100 の処理を開始 ===
# エラー: ページ 76 - ステータスコード 429
# ページ 76 からリポジトリを取得できませんでした。
#
# === ページ 77/100 の処理を開始 ===
# ページ 77 で 10 件のリポジトリを検出
# リポジトリ: rodolfoprr/GoogleMapsAPIv3ProcuraEnderecoAutocomplete, スター数: 52, 言語: None
# リポジトリ: Kubessandra/react-google-calendar-api, スター数: 217, 言語: None
# リポジトリ: s0md3v/goop, スター数: 568, 言語: None
# リポジトリ: Nearsoft/google-code-jam, スター数: 20, 言語: None
# リポジトリ: hibiken/react-places-autocomplete, スター数: 1400, 言語: None
# リポジトリ: JackChan1999/GoogleVR, スター数: 79, 言語: None
# リポジトリ: danthareja/node-google-apps-script, スター数: 351, 言語: None
# リポジトリ: ericz1803/react-google-calendar, スター数: 204, 言語: None
# リポジトリ: angular-ui/ui-map, スター数: 289, 言語: None
# リポジトリ: imranhsayed/google-maps-in-react, スター数: 182, 言語: None
# ページ 77 から 10 件のリポジトリ情報をデータベースに保存しました
# 次のページを取得する前に 3.7 秒待機します...
#
# === ページ 78/100 の処理を開始 ===
# エラー: ページ 78 - ステータスコード 429
# ページ 78 からリポジトリを取得できませんでした。
#
# === ページ 79/100 の処理を開始 ===
# エラー: ページ 79 - ステータスコード 429
# ページ 79 からリポジトリを取得できませんでした。
#
# === ページ 80/100 の処理を開始 ===
# エラー: ページ 80 - ステータスコード 429
# ページ 80 からリポジトリを取得できませんでした。
#
# === ページ 81/100 の処理を開始 ===
# ページ 81 で 10 件のリポジトリを検出
# リポジトリ: rchunping/wxapp-google-analytics, スター数: 363, 言語: None
# リポジトリ: DJI-Mobile-SDK-Tutorials/Android-GSDemo-GoogleMap, スター数: 28, 言語: None
# リポジトリ: nerrorsec/Google-Dorker, スター数: 220, 言語: None
# リポジトリ: lim0606/caffe-googlenet-bn, スター数: 131, 言語: None
# リポジトリ: gimite/google-spreadsheet-ruby, スター数: 307, 言語: None
# リポジトリ: hashicorp/terraform-provider-googleworkspace, スター数: 142, 言語: None
# リポジトリ: kuzmoyev/google-calendar-simple-api, スター数: 668, 言語: None
# リポジトリ: peledies/google-places, スター数: 79, 言語: None
# リポジトリ: sethwebster/GoogleMaps.LocationServices, スター数: 46, 言語: None
# リポジトリ: chtaylo2/Roku-GooglePhotos, スター数: 88, 言語: None
# ページ 81 から 10 件のリポジトリ情報をデータベースに保存しました
# 次のページを取得する前に 2.3 秒待機します...
#
# === ページ 82/100 の処理を開始 ===
# エラー: ページ 82 - ステータスコード 429
# ページ 82 からリポジトリを取得できませんでした。
#
# === ページ 83/100 の処理を開始 ===
# エラー: ページ 83 - ステータスコード 429
# ページ 83 からリポジトリを取得できませんでした。
#
# === ページ 84/100 の処理を開始 ===
# エラー: ページ 84 - ステータスコード 429
# ページ 84 からリポジトリを取得できませんでした。
#
# === ページ 85/100 の処理を開始 ===
# エラー: ページ 85 - ステータスコード 429
# ページ 85 からリポジトリを取得できませんでした。
#
# === ページ 86/100 の処理を開始 ===
# エラー: ページ 86 - ステータスコード 429
# ページ 86 からリポジトリを取得できませんでした。
#
# === ページ 87/100 の処理を開始 ===
# ページ 87 で 10 件のリポジトリを検出
# リポジトリ: GoogleCloudPlatform/generative-ai, スター数: 12100, 言語: None
# リポジトリ: 928799934/googleAuthenticator, スター数: 48, 言語: None
# リポジトリ: rnc-archive/react-native-google-analytics, スター数: 382, 言語: None
# リポジトリ: eschwartz/backbone.googlemaps, スター数: 136, 言語: None
# リポジトリ: pytorch/xla, スター数: 2700, 言語: None
# リポジトリ: anthonyhseb/googlesearch, スター数: 115, 言語: None
# リポジトリ: jcline/fuse-google-drive, スター数: 289, 言語: None
# リポジトリ: google/season-of-docs, スター数: 579, 言語: None
# リポジトリ: wkentaro/gdown, スター数: 5000, 言語: None
# リポジトリ: vially/googlemusic-xbmc, スター数: 180, 言語: None
# ページ 87 から 10 件のリポジトリ情報をデータベースに保存しました
# 次のページを取得する前に 2.2 秒待機します...
#
# === ページ 88/100 の処理を開始 ===
# ページ 88 で 10 件のリポジトリを検出
# リポジトリ: HackSoftware/Django-React-GoogleOauth2-Example, スター数: 129, 言語: None
# リポジトリ: kangguru/rack-google-analytics, スター数: 255, 言語: None
# リポジトリ: mikeroyal/Google-Cloud-Guide, スター数: 177, 言語: None
# リポジトリ: GoogleCloudPlatform/bank-of-anthos, スター数: 1200, 言語: None
# リポジトリ: wizyoung/googletranslate.popclipext, スター数: 377, 言語: None
# リポジトリ: dballinari/GoogleTrends-Scraper, スター数: 216, 言語: None
# リポジトリ: ecthros/uncaptcha, スター数: 2800, 言語: None
# リポジトリ: alexblack/google-fastbutton, スター数: 167, 言語: None
# リポジトリ: masbug/flysystem-google-drive-ext, スター数: 252, 言語: None
# リポジトリ: google/packetdrill, スター数: 950, 言語: None
# ページ 88 から 10 件のリポジトリ情報をデータベースに保存しました
# 次のページを取得する前に 2.7 秒待機します...
#
# === ページ 89/100 の処理を開始 ===
# エラー: ページ 89 - ステータスコード 429
# ページ 89 からリポジトリを取得できませんでした。
#
# === ページ 90/100 の処理を開始 ===
# エラー: ページ 90 - ステータスコード 429
# ページ 90 からリポジトリを取得できませんでした。
#
# === ページ 91/100 の処理を開始 ===
# エラー: ページ 91 - ステータスコード 429
# ページ 91 からリポジトリを取得できませんでした。
#
# === ページ 92/100 の処理を開始 ===
# エラー: ページ 92 - ステータスコード 429
# ページ 92 からリポジトリを取得できませんでした。
#
# === ページ 93/100 の処理を開始 ===
# エラー: ページ 93 - ステータスコード 429
# ページ 93 からリポジトリを取得できませんでした。
#
# === ページ 94/100 の処理を開始 ===
# エラー: ページ 94 - ステータスコード 429
# ページ 94 からリポジトリを取得できませんでした。
#
# === ページ 95/100 の処理を開始 ===
# エラー: ページ 95 - ステータスコード 429
# ページ 95 からリポジトリを取得できませんでした。
#
# === ページ 96/100 の処理を開始 ===
# エラー: ページ 96 - ステータスコード 429
# ページ 96 からリポジトリを取得できませんでした。
#
# === ページ 97/100 の処理を開始 ===
# エラー: ページ 97 - ステータスコード 429
# ページ 97 からリポジトリを取得できませんでした。
#
# === ページ 98/100 の処理を開始 ===
# ページ 98 で 10 件のリポジトリを検出
# リポジトリ: matlink/gplaycli, スター数: 1100, 言語: None
# リポジトリ: itsmikepowers/google-maps-easy-scrape, スター数: 101, 言語: None
# リポジトリ: mautrix/googlechat, スター数: 121, 言語: None
# リポジトリ: ClaudiuGeorgiu/PlaystoreDownloader, スター数: 1200, 言語: None
# リポジトリ: googleads/google-ads-ruby, スター数: 78, 言語: None
# リポジトリ: nviennot/playdrone, スター数: 423, 言語: None
# リポジトリ: google/google-drive-shell-extension, スター数: 159, 言語: None
# リポジトリ: maple3142/GDIndex, スター数: 1900, 言語: None
# リポジトリ: GoogleChrome/samples, スター数: 5800, 言語: None
# リポジトリ: mazipan/vue-google-adsense, スター数: 258, 言語: None
# ページ 98 から 10 件のリポジトリ情報をデータベースに保存しました
# 次のページを取得する前に 3.5 秒待機します...
#
# === ページ 99/100 の処理を開始 ===
# ページ 99 で 10 件のリポジトリを検出
# リポジトリ: ankurk91/google-chat-electron, スター数: 168, 言語: None
# リポジトリ: pbugnion/gmaps, スター数: 761, 言語: None
# リポジトリ: jarrodwatts/code-like-google, スター数: 123, 言語: None
# リポジトリ: elharony/google-mobile-web-specialist-certification-guide, スター数: 221, 言語: None
# リポジトリ: nqthaivl/Copy-Folder-Google-Drive-to-Google-Drive, スター数: 57, 言語: None
# リポジトリ: max-barry/google-drive-cms, スター数: 400, 言語: None
# リポジトリ: jenkins-x/terraform-google-jx, スター数: 37, 言語: None
# リポジトリ: kitasuke/GoogleMaterialIconFont, スター数: 147, 言語: None
# リポジトリ: alyssaxuu/figma-to-google-slides, スター数: 568, 言語: None
# リポジトリ: terraform-google-modules/terraform-google-lb-internal, スター数: 86, 言語: None
# ページ 99 から 10 件のリポジトリ情報をデータベースに保存しました
# 次のページを取得する前に 3.2 秒待機します...
#
# === ページ 100/100 の処理を開始 ===
# ページ 100 で 10 件のリポジトリを検出
# リポジトリ: jyaganeh/android-google-maps-demo, スター数: 11, 言語: None
# リポジトリ: cpinan/Cocos2dX_GooglePlayGamesServices, スター数: 64, 言語: None
# リポジトリ: erebusnz/gapi-google-analytics-php-interface, スター数: 166, 言語: None
# リポジトリ: ericyd/gdrive-copy, スター数: 1600, 言語: None
# リポジトリ: terraform-google-modules/terraform-google-org-policy, スター数: 95, 言語: None
# リポジトリ: veritas501/Potplayer-Subtitle-Translate-GoogleFix, スター数: 126, 言語: None
# リポジトリ: danielireson/google-sheets-blog-cms, スター数: 212, 言語: None
# リポジトリ: google/googlesre, スター数: 167, 言語: None
# リポジトリ: godot-sdk-integrations/godot-google-play-billing, スター数: 228, 言語: None
# リポジトリ: GoogleCloudPlatform/terraform-google-three-tier-web-app, スター数: 134, 言語: None
# ページ 100 から 10 件のリポジトリ情報をデータベースに保存しました
# 次のページを取得する前に 3.9 秒待機します...
#
# 合計 320 件のリポジトリ情報をデータベースに保存しました
#
# === データベースに保存された全リポジトリ情報 ===
# 総レコード数: 320
#
# ID | リポジトリ名 | スター数 | 言語 | 取得日時
# --------------------------------------------------------------------------------
# 1 | gaowanlu/google | 341 | NULL | 2025-11-25 05:33:26
# 2 | google/googletest | 37500 | NULL | 2025-11-25 05:33:26
# 3 | google-research/google-research | 36800 | NULL | 2025-11-25 05:33:26
# 4 | googleapis/googleapis | 8300 | NULL | 2025-11-25 05:33:26
# 5 | NikolaiT/GoogleScraper | 2800 | NULL | 2025-11-25 05:33:26
# 6 | PHPGangsta/GoogleAuthenticator | 2300 | NULL | 2025-11-25 05:33:26
# 7 | zh-google-styleguide/zh-google-styleguide | 10900 | NULL | 2025-11-25 05:33:26
# 8 | opauth/google | 120 | NULL | 2025-11-25 05:33:26
# 9 | googlesamples/google-services | 3200 | NULL | 2025-11-25 05:33:26
# 10 | Ponderfly/GoogleTranslateIpCheck | 5000 | NULL | 2025-11-25 05:33:26
# 11 | googleapis/google-cloud-python | 5200 | NULL | 2025-11-25 05:33:33
# 12 | google/google-authenticator | 5300 | NULL | 2025-11-25 05:33:33
# 13 | priyankavergadia/google-cloud-4-words | 8200 | NULL | 2025-11-25 05:33:33
# 14 | TheLastGimbus/GooglePhotosTakeoutHelper | 5200 | NULL | 2025-11-25 05:33:33
# 15 | jarun/googler | 6200 | NULL | 2025-11-25 05:33:33
# 16 | justjavac/Google-IPs | 3500 | NULL | 2025-11-25 05:33:33
# 17 | wstrange/GoogleAuth | 1100 | NULL | 2025-11-25 05:33:33
# 18 | googleapis/google-cloud-go | 4400 | NULL | 2025-11-25 05:33:33
# 19 | hashicorp/terraform-provider-google | 2600 | NULL | 2025-11-25 05:33:33
# 20 | react-native-google-signin/google-signin | 3500 | NULL | 2025-11-25 05:33:33
# 21 | matheuss/google-translate-api | 3100 | NULL | 2025-11-25 05:33:41
# 22 | google/iosched | 21800 | NULL | 2025-11-25 05:33:41
# 23 | Kerrick/google | 116 | NULL | 2025-11-25 05:33:41
# 24 | google/automl | 6400 | NULL | 2025-11-25 05:33:41
# 25 | meibenjin/GoogleSearchCrawler | 401 | NULL | 2025-11-25 05:33:41
# 26 | MarioVilas/googlesearch | 1200 | NULL | 2025-11-25 05:33:41
# 27 | googleapis/google-api-ruby-client | 2900 | NULL | 2025-11-25 05:33:41
# 28 | justjavac/ReplaceGoogleCDN | 3600 | NULL | 2025-11-25 05:33:41
# 29 | terraform-google-modules/terraform-google-network | 473 | NULL | 2025-11-25 05:33:41
# 30 | terraform-google-modules/terraform-google-kubernetes-engine | 1200 | NULL | 2025-11-25 05:33:41
# 31 | FaridSafi/react-native-google-places-autocomplete | 2100 | NULL | 2025-11-25 05:33:52
# 32 | anthonyjgrove/react-google-login | 1800 | NULL | 2025-11-25 05:33:52
# 33 | mgechev/google-interview-preparation-problems | 3200 | NULL | 2025-11-25 05:33:52
# 34 | omkarcloud/google-maps-scraper | 2200 | NULL | 2025-11-25 05:33:52
# 35 | better319/google-access-helper | 55 | NULL | 2025-11-25 05:33:52
# 36 | darcyliu/google-styleguide | 1400 | NULL | 2025-11-25 05:33:52
# 37 | APCSLowell/GoogleBillboard | 3 | NULL | 2025-11-25 05:33:52
# 38 | prasmussen/gdrive | 9000 | NULL | 2025-11-25 05:33:52
# 39 | BrandonPotter/GoogleAuthenticator | 390 | NULL | 2025-11-25 05:33:52
# 40 | egirault/googleplay-api | 895 | NULL | 2025-11-25 05:33:52
# 41 | Stichoza/google-translate-php | 1900 | NULL | 2025-11-25 05:33:57
# 42 | lypeer/GoogleClock | 790 | NULL | 2025-11-25 05:33:57
# 43 | GuillaumeLeclerc/vue-google-maps | 562 | NULL | 2025-11-25 05:33:57
# 44 | google/fonts | 19400 | NULL | 2025-11-25 05:33:57
# 45 | aryanvikash/Google-Drive-Uploader | 306 | NULL | 2025-11-25 05:33:57
# 46 | errata-ai/Google | 78 | NULL | 2025-11-25 05:33:57
# 47 | EddyVerbruggen/cordova-plugin-googleplus | 567 | NULL | 2025-11-25 05:33:57
# 48 | GoogleCloudPlatform/python-docs-samples | 7900 | NULL | 2025-11-25 05:33:57
# 49 | gosom/google-maps-scraper | 2500 | NULL | 2025-11-25 05:33:57
# 50 | cobaltdisco/Google-Chinese-Results-Blocklist | 7500 | NULL | 2025-11-25 05:33:57
# 51 | googleapis/google-cloud-php | 1200 | NULL | 2025-11-25 05:34:02
# 52 | ssnhd/googlevoice | 2000 | NULL | 2025-11-25 05:34:02
# 53 | googleapis/elixir-google-api | 1100 | NULL | 2025-11-25 05:34:02
# 54 | oazabir/GoogleDoc2Html | 142 | NULL | 2025-11-25 05:34:02
# 55 | googleapis/google-api-dotnet-client | 1500 | NULL | 2025-11-25 05:34:02
# 56 | rakannimer/react-google-charts | 1700 | NULL | 2025-11-25 05:34:02
# 57 | google/it-cert-automation-practice | 986 | NULL | 2025-11-25 05:34:02
# 58 | JustFly1984/react-google-maps-api | 2000 | NULL | 2025-11-25 05:34:02
# 59 | google/google-api-java-client-samples | 741 | NULL | 2025-11-25 05:34:02
# 60 | googleads/google-ads-python | 627 | NULL | 2025-11-25 05:34:02
# 61 | elmoallistair/google-it-automation | 516 | NULL | 2025-11-25 05:34:08
# 62 | apneadiving/Google-Maps-for-Rails | 2300 | NULL | 2025-11-25 05:34:08
# 63 | googleapis/google-http-java-client | 1400 | NULL | 2025-11-25 05:34:08
# 64 | Iceloof/GoogleNews | 374 | NULL | 2025-11-25 05:34:08
# 65 | googleapis/google-auth-library-nodejs | 1900 | NULL | 2025-11-25 05:34:08
# 66 | Ibit-to/google-unlocked | 2300 | NULL | 2025-11-25 05:34:08
# 67 | Melvin-Abraham/Google-Assistant-Unofficial-Desktop-Client | 3600 | NULL | 2025-11-25 05:34:08
# 68 | cgapps/vendor_google | 345 | NULL | 2025-11-25 05:34:08
# 69 | jennybc/googlesheets | 784 | NULL | 2025-11-25 05:34:08
# 70 | zquestz/omniauth-google-oauth2 | 1500 | NULL | 2025-11-25 05:34:08
# 71 | xamarin/GoogleApisForiOSComponents | 220 | NULL | 2025-11-25 05:34:13
# 72 | googleapis/google-cloud-cpp | 628 | NULL | 2025-11-25 05:34:13
# 73 | xamarin/GooglePlayServicesComponents | 314 | NULL | 2025-11-25 05:34:13
# 74 | chimbori/google-calendar-crx | 952 | NULL | 2025-11-25 05:34:13
# 75 | entaq/GoogleAppsScript | 266 | NULL | 2025-11-25 05:34:13
# 76 | Kdyby/Google | 25 | NULL | 2025-11-25 05:34:13
# 77 | hongtaocai/googlefinance | 807 | NULL | 2025-11-25 05:34:13
# 78 | macek/google_pacman | 504 | NULL | 2025-11-25 05:34:13
# 79 | firmai/awesome-google-colab | 1500 | NULL | 2025-11-25 05:34:13
# 80 | Proviesec/google-dorks | 1100 | NULL | 2025-11-25 05:34:13
# 81 | Akdeniz/google-play-crawler | 588 | NULL | 2025-11-25 05:34:42
# 82 | googleapis/google-oauth-java-client | 644 | NULL | 2025-11-25 05:34:42
# 83 | tidyverse/googlesheets4 | 372 | NULL | 2025-11-25 05:34:42
# 84 | react-native-google-cast/react-native-google-cast | 691 | NULL | 2025-11-25 05:34:42
# 85 | google/earthenterprise | 2700 | NULL | 2025-11-25 05:34:42
# 86 | gaspa93/googlemaps-scraper | 485 | NULL | 2025-11-25 05:34:42
# 87 | cvdfoundation/google-landmark | 817 | NULL | 2025-11-25 05:34:42
# 88 | enuchi/React-Google-Apps-Script | 1500 | NULL | 2025-11-25 05:34:42
# 89 | googleapis/google-api-java-client-services | 692 | NULL | 2025-11-25 05:34:42
# 90 | fysoul17/google_maps_place_picker | 229 | NULL | 2025-11-25 05:34:42
# 91 | GoogleCloudPlatform/awesome-google-cloud | 876 | NULL | 2025-11-25 05:34:46
# 92 | googleworkspace/apps-script-samples | 5000 | NULL | 2025-11-25 05:34:46
# 93 | rafiuddinkhan/Yolo-Training-GoogleColab | 170 | NULL | 2025-11-25 05:34:46
# 94 | tolu360/react-native-google-places | 569 | NULL | 2025-11-25 05:34:46
# 95 | r0adkll/upload-google-play | 924 | NULL | 2025-11-25 05:34:46
# 96 | FugiTech/google-meet-grid-view | 617 | NULL | 2025-11-25 05:34:46
# 97 | googleapis/google-auth-library-php | 1400 | NULL | 2025-11-25 05:34:46
# 98 | dozoisch/react-google-recaptcha | 1100 | NULL | 2025-11-25 05:34:46
# 99 | heroku/heroku-buildpack-google-chrome | 298 | NULL | 2025-11-25 05:34:46
# 100 | alx-xlx/goindex | 1300 | NULL | 2025-11-25 05:34:46
# 101 | mattwilson1024/google-photos-exif | 1000 | NULL | 2025-11-25 05:34:51
# 102 | nlintz/TensorFlow-Tutorials | 6000 | NULL | 2025-11-25 05:34:51
# 103 | jmartinesp/GoogleNavigationDrawerMenu | 275 | NULL | 2025-11-25 05:34:51
# 104 | K0rz3n/GoogleHacking-Page | 290 | NULL | 2025-11-25 05:34:51
# 105 | androidthings/sample-googleassistant | 468 | NULL | 2025-11-25 05:34:51
# 106 | Ayush7-BIT/Google-Facilitator-Program-Solutions | 147 | NULL | 2025-11-25 05:34:51
# 107 | AbhimanyuForiOS/GoogleNewsStandAnimation | 659 | NULL | 2025-11-25 05:34:51
# 108 | hermanho/MMM-GooglePhotos | 192 | NULL | 2025-11-25 05:34:51
# 109 | revolunet/angular-google-analytics | 649 | NULL | 2025-11-25 05:34:51
# 110 | googleapis/google-auth-library-ruby | 496 | NULL | 2025-11-25 05:34:51
# 111 | PMassicotte/gtrendsR | 363 | NULL | 2025-11-25 05:34:57
# 112 | idehub/react-native-google-analytics-bridge | 1200 | NULL | 2025-11-25 05:34:57
# 113 | HandsOnDataViz/leaflet-maps-with-google-sheets | 158 | NULL | 2025-11-25 05:34:57
# 114 | hpneo/gmaps | 7000 | NULL | 2025-11-25 05:34:57
# 115 | cevoaustralia/aws-google-auth | 546 | NULL | 2025-11-25 05:34:57
# 116 | playgameservices/play-games-plugin-for-unity | 3600 | NULL | 2025-11-25 05:34:57
# 117 | sahava/GoogleTagManagerTemplates | 203 | NULL | 2025-11-25 05:34:57
# 118 | Freika/dawarich | 7300 | NULL | 2025-11-25 05:34:57
# 119 | googleads/googleads-shopping-samples | 201 | NULL | 2025-11-25 05:34:57
# 120 | googleapis/google-auth-library-java | 450 | NULL | 2025-11-25 05:34:57
# 121 | noelportugal/google-home-notifier | 575 | NULL | 2025-11-25 05:35:02
# 122 | google/WebFundamentals | 13900 | NULL | 2025-11-25 05:35:02
# 123 | actions-on-google/actions-on-google-nodejs | 896 | NULL | 2025-11-25 05:35:02
# 124 | ohyicong/Google-Image-Scraper | 543 | NULL | 2025-11-25 05:35:02
# 125 | Iku/Google-Forms-to-Discord | 556 | NULL | 2025-11-25 05:35:02
# 126 | FKLC/Torrent-To-Google-Drive-Downloader | 389 | NULL | 2025-11-25 05:35:02
# 127 | alexpechkarev/google-maps | 558 | NULL | 2025-11-25 05:35:02
# 128 | slimkrazy/python-google-places | 523 | NULL | 2025-11-25 05:35:02
# 129 | labbots/google-drive-upload | 732 | NULL | 2025-11-25 05:35:02
# 130 | femmebot/google-type | 1000 | NULL | 2025-11-25 05:35:02
# 131 | BaltiApps/Pixelify-Google-Photos | 1500 | NULL | 2025-11-25 05:35:08
# 132 | google/googleapis.dart | 408 | NULL | 2025-11-25 05:35:08
# 133 | Code-Bullet/Google-Chrome-Dino-Game-AI | 689 | NULL | 2025-11-25 05:35:08
# 134 | elmoallistair/google-it-support | 338 | NULL | 2025-11-25 05:35:08
# 135 | humazed/google_map_location_picker | 206 | NULL | 2025-11-25 05:35:08
# 136 | brendanhay/gogol | 294 | NULL | 2025-11-25 05:35:08
# 137 | egeloen/ivory-google-map | 323 | NULL | 2025-11-25 05:35:08
# 138 | BlankCoders/GoogleKickStart2020_Solutions | 188 | NULL | 2025-11-25 05:35:08
# 139 | hariharan-uno/google | 27 | NULL | 2025-11-25 05:35:08
# 140 | jmelosegui/GooglemapMvc | 118 | NULL | 2025-11-25 05:35:08
# 141 | yireo/Yireo_GoogleTagManager2 | 163 | NULL | 2025-11-25 05:35:17
# 142 | jaredhanson/passport-google-oauth2 | 839 | NULL | 2025-11-25 05:35:17
# 143 | adrianhajdin/project_google_clone | 470 | NULL | 2025-11-25 05:35:17
# 144 | GoogleCloudPlatform/magic-modules | 908 | NULL | 2025-11-25 05:35:17
# 145 | invertase/react-native-google-mobile-ads | 935 | NULL | 2025-11-25 05:35:17
# 146 | ArdiArtani/Google-Drive-Player-Script | 319 | NULL | 2025-11-25 05:35:17
# 147 | google-gemini/starter-applets | 1200 | NULL | 2025-11-25 05:35:17
# 148 | tgtsml/QtInputMethod_GooglePinyin | 131 | NULL | 2025-11-25 05:35:17
# 149 | GoogleCloudPlatform/nodejs-docs-samples | 2900 | NULL | 2025-11-25 05:35:17
# 150 | howie6879/magic_google | 408 | NULL | 2025-11-25 05:35:17
# 151 | priyankavergadia/AppointmentScheduler-GoogleCalendar | 97 | NULL | 2025-11-25 05:35:41
# 152 | daviddrysdale/python-phonenumbers | 3700 | NULL | 2025-11-25 05:35:41
# 153 | n3a9/google-foobar | 301 | NULL | 2025-11-25 05:35:41
# 154 | igrigorik/videospeed | 4200 | NULL | 2025-11-25 05:35:41
# 155 | google/google-input-tools | 265 | NULL | 2025-11-25 05:35:41
# 156 | kubernetes/cloud-provider-gcp | 144 | NULL | 2025-11-25 05:35:41
# 157 | randomBrainstormer/MMM-GoogleCalendar | 89 | NULL | 2025-11-25 05:35:41
# 158 | JasonSanford/geojson-google-maps | 323 | NULL | 2025-11-25 05:35:41
# 159 | paralelo14/google_explorer | 205 | NULL | 2025-11-25 05:35:41
# 160 | steverichey/google-play-badge-svg | 183 | NULL | 2025-11-25 05:35:41
# 161 | neokree/GoogleNavigationDrawer | 157 | NULL | 2025-11-25 05:35:57
# 162 | stepancheg/rust-protobuf | 3000 | NULL | 2025-11-25 05:35:57
# 163 | zeantsoi/GoogleBooks | 112 | NULL | 2025-11-25 05:35:57
# 164 | Akryum/vue-googlemaps | 533 | NULL | 2025-11-25 05:35:57
# 165 | googleworkspace/python-samples | 1300 | NULL | 2025-11-25 05:35:57
# 166 | gabrielpacheco23/google-translator | 190 | NULL | 2025-11-25 05:35:57
# 167 | zjuyxy/google200 | 106 | NULL | 2025-11-25 05:35:57
# 168 | veip007/GV_GoogleVoice | 149 | NULL | 2025-11-25 05:35:57
# 169 | Gowee/GoogleMirror | 89 | NULL | 2025-11-25 05:35:57
# 170 | pkpio/fitbit-googlefit | 508 | NULL | 2025-11-25 05:35:57
# 171 | GoogleCloudPlatform/java-docs-samples | 1900 | NULL | 2025-11-25 05:36:03
# 172 | joshcarty/google-searchconsole | 233 | NULL | 2025-11-25 05:36:03
# 173 | vadimdemedes/google-images | 307 | NULL | 2025-11-25 05:36:03
# 174 | madisona/django-google-maps | 282 | NULL | 2025-11-25 05:36:03
# 175 | googleanalytics/google-analytics-plugin-for-unity | 397 | NULL | 2025-11-25 05:36:03
# 176 | google/coding-competitions-archive | 1300 | NULL | 2025-11-25 05:36:03
# 177 | TheMuppets/proprietary_vendor_google | 101 | NULL | 2025-11-25 05:36:03
# 178 | RubyMoney/google_currency | 182 | NULL | 2025-11-25 05:36:03
# 179 | subnub/myDrive | 4100 | NULL | 2025-11-25 05:36:03
# 180 | pulkitjalan/google-apiclient | 257 | NULL | 2025-11-25 05:36:03
# 181 | tidyverse/googledrive | 336 | NULL | 2025-11-25 05:36:09
# 182 | roboguice/roboguice | 3800 | NULL | 2025-11-25 05:36:09
# 183 | Hameds/GoogleBackup | 284 | NULL | 2025-11-25 05:36:09
# 184 | mate-academy/py-can-access-google-page | 2 | NULL | 2025-11-25 05:36:09
# 185 | chocoboyx/GoogleSheet_DiscordBot | 7 | NULL | 2025-11-25 05:36:09
# 186 | terraform-google-modules/terraform-google-pubsub | 107 | NULL | 2025-11-25 05:36:09
# 187 | spatie/laravel-googletagmanager | 430 | NULL | 2025-11-25 05:36:09
# 188 | xfslove/alfred-google-translate | 617 | NULL | 2025-11-25 05:36:09
# 189 | smol-ai/GodMode | 4300 | NULL | 2025-11-25 05:36:09
# 190 | google/google-api-ruby-client-samples | 330 | NULL | 2025-11-25 05:36:09
# 191 | 5iux/sou | 940 | NULL | 2025-11-25 05:36:14
# 192 | CVM/Magento_GoogleTagManager | 67 | NULL | 2025-11-25 05:36:14
# 193 | forseti-security/terraform-google-forseti | 133 | NULL | 2025-11-25 05:36:14
# 194 | tanmuhittin/laravel-google-translate | 430 | NULL | 2025-11-25 05:36:14
# 195 | DarkSnakeGang/GoogleSnakeModLoader | 50 | NULL | 2025-11-25 05:36:14
# 196 | jignesh13/googlecalendar | 178 | NULL | 2025-11-25 05:36:14
# 197 | akshaaatt/Google-IAP | 282 | NULL | 2025-11-25 05:36:14
# 198 | GoogleWebComponents/google-analytics | 186 | NULL | 2025-11-25 05:36:14
# 199 | thephpleague/oauth2-google | 410 | NULL | 2025-11-25 05:36:14
# 200 | jupyterlab/jupyterlab-google-drive | 402 | NULL | 2025-11-25 05:36:14
# 201 | bpillon/google_maps_cluster_manager | 140 | NULL | 2025-11-25 05:36:20
# 202 | devstark-com/vue-google-charts | 447 | NULL | 2025-11-25 05:36:20
# 203 | pseudomuto/protoc-gen-doc | 2800 | NULL | 2025-11-25 05:36:20
# 204 | GoogleCloudPlatform/terraform-google-cloud-run | 187 | NULL | 2025-11-25 05:36:20
# 205 | maximepvrt/angular-google-gapi | 174 | NULL | 2025-11-25 05:36:20
# 206 | googleads/googleads-dfa-reporting-samples | 109 | NULL | 2025-11-25 05:36:20
# 207 | akexorcist/GoogleDirectionAndPlaceLibrary | 117 | NULL | 2025-11-25 05:36:20
# 208 | google-pay/google-pay-button | 288 | NULL | 2025-11-25 05:36:20
# 209 | googlesamples/web-fundamentals | 315 | NULL | 2025-11-25 05:36:20
# 210 | googlearchive/drive-zipextractor | 441 | NULL | 2025-11-25 05:36:20
# 211 | charlierguo/gmail | 1800 | NULL | 2025-11-25 05:36:25
# 212 | bluevisiontec/GoogleShoppingApi | 69 | NULL | 2025-11-25 05:36:25
# 213 | invokable/laravel-google-sheets | 440 | NULL | 2025-11-25 05:36:25
# 214 | wanze/Google-Analytics-API-PHP | 261 | NULL | 2025-11-25 05:36:25
# 215 | cohnen/mcp-google-ads | 326 | NULL | 2025-11-25 05:36:25
# 216 | todc/todc-bootstrap | 2100 | NULL | 2025-11-25 05:36:25
# 217 | protocolbuffers/protobuf-go | 3300 | NULL | 2025-11-25 05:36:25
# 218 | andresoviedo/google-drive-ftp-adapter | 399 | NULL | 2025-11-25 05:36:25
# 219 | vladest/googlemaps | 148 | NULL | 2025-11-25 05:36:25
# 220 | google-map-react/google-map-react-examples | 148 | NULL | 2025-11-25 05:36:25
# 221 | mister0/How-to-prepare-for-google-interview-SWE-SRE | 714 | NULL | 2025-11-25 05:36:43
# 222 | YoongiKim/AutoCrawler | 1700 | NULL | 2025-11-25 05:36:43
# 223 | zachysaur/Google | 13 | NULL | 2025-11-25 05:36:43
# 224 | chentinghao/download_google_drive | 201 | NULL | 2025-11-25 05:36:43
# 225 | visionmedia/google-search | 263 | NULL | 2025-11-25 05:36:43
# 226 | yireo-magento1/Yireo_GoogleTagManager | 56 | NULL | 2025-11-25 05:36:43
# 227 | aaronpk/Google-Voice-PHP-API | 224 | NULL | 2025-11-25 05:36:43
# 228 | mgilangjanuar/teledrive | 2000 | NULL | 2025-11-25 05:36:43
# 229 | capacitor-community/google-maps | 158 | NULL | 2025-11-25 05:36:43
# 230 | twinslash/redmine_omniauth_google | 99 | NULL | 2025-11-25 05:36:43
# 231 | kakone/GoogleCast | 146 | NULL | 2025-11-25 05:36:47
# 232 | google/comprehensive-rust | 32299 | NULL | 2025-11-25 05:36:47
# 233 | CyanogenMod/android_device_lge_mako | 112 | NULL | 2025-11-25 05:36:47
# 234 | i8beef/HomeAutio.Mqtt.GoogleHome | 229 | NULL | 2025-11-25 05:36:47
# 235 | googleads/googleads-ima-android | 119 | NULL | 2025-11-25 05:36:47
# 236 | umano/AndroidSlidingUpPanel | 9500 | NULL | 2025-11-25 05:36:47
# 237 | gruntwork-io/terraform-google-sql | 92 | NULL | 2025-11-25 05:36:47
# 238 | myguybetter/GoogleIPHunter | 60 | NULL | 2025-11-25 05:36:47
# 239 | ivangrov/YOLOv3-GoogleColab | 79 | NULL | 2025-11-25 05:36:47
# 240 | firstcomdigital/Google-Interview-University | 240 | NULL | 2025-11-25 05:36:47
# 241 | geniusgithub/AndroidDialer | 196 | NULL | 2025-11-25 05:36:55
# 242 | YukiGasai/obsidian-google-calendar | 464 | NULL | 2025-11-25 05:36:55
# 243 | retroplasma/earth-reverse-engineering | 2300 | NULL | 2025-11-25 05:36:55
# 244 | yrq110/TinyGoogle | 181 | NULL | 2025-11-25 05:36:55
# 245 | actions-on-google/dialogflow-facts-about-google-nodejs | 185 | NULL | 2025-11-25 05:36:55
# 246 | GoogleCloudPlatform/dotnet-docs-samples | 806 | NULL | 2025-11-25 05:36:55
# 247 | xob0t/Google-Photos-Toolkit | 636 | NULL | 2025-11-25 05:36:55
# 248 | marcferna/CakePHP-GoogleMapHelper | 63 | NULL | 2025-11-25 05:36:55
# 249 | clintecker/django-google-analytics | 172 | NULL | 2025-11-25 05:36:55
# 250 | angulartics/angulartics-google-analytics | 130 | NULL | 2025-11-25 05:36:55
# 251 | rodolfoprr/GoogleMapsAPIv3ProcuraEnderecoAutocomplete | 52 | NULL | 2025-11-25 05:37:02
# 252 | Kubessandra/react-google-calendar-api | 217 | NULL | 2025-11-25 05:37:02
# 253 | s0md3v/goop | 568 | NULL | 2025-11-25 05:37:02
# 254 | Nearsoft/google-code-jam | 20 | NULL | 2025-11-25 05:37:02
# 255 | hibiken/react-places-autocomplete | 1400 | NULL | 2025-11-25 05:37:02
# 256 | JackChan1999/GoogleVR | 79 | NULL | 2025-11-25 05:37:02
# 257 | danthareja/node-google-apps-script | 351 | NULL | 2025-11-25 05:37:02
# 258 | ericz1803/react-google-calendar | 204 | NULL | 2025-11-25 05:37:02
# 259 | angular-ui/ui-map | 289 | NULL | 2025-11-25 05:37:02
# 260 | imranhsayed/google-maps-in-react | 182 | NULL | 2025-11-25 05:37:02
# 261 | rchunping/wxapp-google-analytics | 363 | NULL | 2025-11-25 05:37:12
# 262 | DJI-Mobile-SDK-Tutorials/Android-GSDemo-GoogleMap | 28 | NULL | 2025-11-25 05:37:12
# 263 | nerrorsec/Google-Dorker | 220 | NULL | 2025-11-25 05:37:12
# 264 | lim0606/caffe-googlenet-bn | 131 | NULL | 2025-11-25 05:37:12
# 265 | gimite/google-spreadsheet-ruby | 307 | NULL | 2025-11-25 05:37:12
# 266 | hashicorp/terraform-provider-googleworkspace | 142 | NULL | 2025-11-25 05:37:12
# 267 | kuzmoyev/google-calendar-simple-api | 668 | NULL | 2025-11-25 05:37:12
# 268 | peledies/google-places | 79 | NULL | 2025-11-25 05:37:12
# 269 | sethwebster/GoogleMaps.LocationServices | 46 | NULL | 2025-11-25 05:37:12
# 270 | chtaylo2/Roku-GooglePhotos | 88 | NULL | 2025-11-25 05:37:12
# 271 | GoogleCloudPlatform/generative-ai | 12100 | NULL | 2025-11-25 05:37:34
# 272 | 928799934/googleAuthenticator | 48 | NULL | 2025-11-25 05:37:34
# 273 | rnc-archive/react-native-google-analytics | 382 | NULL | 2025-11-25 05:37:34
# 274 | eschwartz/backbone.googlemaps | 136 | NULL | 2025-11-25 05:37:34
# 275 | pytorch/xla | 2700 | NULL | 2025-11-25 05:37:34
# 276 | anthonyhseb/googlesearch | 115 | NULL | 2025-11-25 05:37:34
# 277 | jcline/fuse-google-drive | 289 | NULL | 2025-11-25 05:37:34
# 278 | google/season-of-docs | 579 | NULL | 2025-11-25 05:37:34
# 279 | wkentaro/gdown | 5000 | NULL | 2025-11-25 05:37:34
# 280 | vially/googlemusic-xbmc | 180 | NULL | 2025-11-25 05:37:34
# 281 | HackSoftware/Django-React-GoogleOauth2-Example | 129 | NULL | 2025-11-25 05:37:39
# 282 | kangguru/rack-google-analytics | 255 | NULL | 2025-11-25 05:37:39
# 283 | mikeroyal/Google-Cloud-Guide | 177 | NULL | 2025-11-25 05:37:39
# 284 | GoogleCloudPlatform/bank-of-anthos | 1200 | NULL | 2025-11-25 05:37:39
# 285 | wizyoung/googletranslate.popclipext | 377 | NULL | 2025-11-25 05:37:39
# 286 | dballinari/GoogleTrends-Scraper | 216 | NULL | 2025-11-25 05:37:39
# 287 | ecthros/uncaptcha | 2800 | NULL | 2025-11-25 05:37:39
# 288 | alexblack/google-fastbutton | 167 | NULL | 2025-11-25 05:37:39
# 289 | masbug/flysystem-google-drive-ext | 252 | NULL | 2025-11-25 05:37:39
# 290 | google/packetdrill | 950 | NULL | 2025-11-25 05:37:39
# 291 | matlink/gplaycli | 1100 | NULL | 2025-11-25 05:37:56
# 292 | itsmikepowers/google-maps-easy-scrape | 101 | NULL | 2025-11-25 05:37:56
# 293 | mautrix/googlechat | 121 | NULL | 2025-11-25 05:37:56
# 294 | ClaudiuGeorgiu/PlaystoreDownloader | 1200 | NULL | 2025-11-25 05:37:56
# 295 | googleads/google-ads-ruby | 78 | NULL | 2025-11-25 05:37:56
# 296 | nviennot/playdrone | 423 | NULL | 2025-11-25 05:37:56
# 297 | google/google-drive-shell-extension | 159 | NULL | 2025-11-25 05:37:56
# 298 | maple3142/GDIndex | 1900 | NULL | 2025-11-25 05:37:56
# 299 | GoogleChrome/samples | 5800 | NULL | 2025-11-25 05:37:56
# 300 | mazipan/vue-google-adsense | 258 | NULL | 2025-11-25 05:37:56
# 301 | ankurk91/google-chat-electron | 168 | NULL | 2025-11-25 05:38:02
# 302 | pbugnion/gmaps | 761 | NULL | 2025-11-25 05:38:02
# 303 | jarrodwatts/code-like-google | 123 | NULL | 2025-11-25 05:38:02
# 304 | elharony/google-mobile-web-specialist-certification-guide | 221 | NULL | 2025-11-25 05:38:02
# 305 | nqthaivl/Copy-Folder-Google-Drive-to-Google-Drive | 57 | NULL | 2025-11-25 05:38:02
# 306 | max-barry/google-drive-cms | 400 | NULL | 2025-11-25 05:38:02
# 307 | jenkins-x/terraform-google-jx | 37 | NULL | 2025-11-25 05:38:02
# 308 | kitasuke/GoogleMaterialIconFont | 147 | NULL | 2025-11-25 05:38:02
# 309 | alyssaxuu/figma-to-google-slides | 568 | NULL | 2025-11-25 05:38:02
# 310 | terraform-google-modules/terraform-google-lb-internal | 86 | NULL | 2025-11-25 05:38:02
# 311 | jyaganeh/android-google-maps-demo | 11 | NULL | 2025-11-25 05:38:07
# 312 | cpinan/Cocos2dX_GooglePlayGamesServices | 64 | NULL | 2025-11-25 05:38:07
# 313 | erebusnz/gapi-google-analytics-php-interface | 166 | NULL | 2025-11-25 05:38:07
# 314 | ericyd/gdrive-copy | 1600 | NULL | 2025-11-25 05:38:07
# 315 | terraform-google-modules/terraform-google-org-policy | 95 | NULL | 2025-11-25 05:38:07
# 316 | veritas501/Potplayer-Subtitle-Translate-GoogleFix | 126 | NULL | 2025-11-25 05:38:07
# 317 | danielireson/google-sheets-blog-cms | 212 | NULL | 2025-11-25 05:38:07
# 318 | google/googlesre | 167 | NULL | 2025-11-25 05:38:07
# 319 | godot-sdk-integrations/godot-google-play-billing | 228 | NULL | 2025-11-25 05:38:07
# 320 | GoogleCloudPlatform/terraform-google-three-tier-web-app | 134 | NULL | 2025-11-25 05:38:07
